# %% [markdown]
# <a href="https://colab.research.google.com/github/rachnaa-s/-js-js/blob/main/LAB_1_Weather_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from google.colab import files


API_KEY = "YOUR_API_KEY"
CITIES = ["Delhi", "Mumbai", "Bangalore", "Kolkata", "Chennai", "Indore"]

weather_data = []


for city in CITIES:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        weather_info = {
            "City": city,
            "Temperature_C": data["main"]["temp"],
            "Feels_Like_C": data["main"]["feels_like"],
            "Humidity_%": data["main"]["humidity"],
            "Pressure_hPa": data["main"]["pressure"],
            "Wind_Speed_m_s": data["wind"]["speed"],
            "Weather_Condition": data["weather"][0]["main"]
        }
        weather_data.append(weather_info)
    else:
        print(f"Failed to fetch data for {city}")

# 3. Create DataFrame
df = pd.DataFrame(weather_data)


csv_filename = "weather_ml_dataset.csv"
df.to_csv(csv_filename, index=False)

print("Data fetched successfully!")
display(df.head())


files.download(csv_filename)
# Out:
# Data fetched successfully!
#         City  Temperature_C  Feels_Like_C  Humidity_%  Pressure_hPa  \
# 0      Delhi          30.46         35.66          68           999
# 1     Mumbai          27.93         32.08          81          1007
# 2  Bangalore          22.16         22.65          85          1011
# 3    Kolkata          26.72         30.12          92          1003
# 4    Chennai          28.94         35.68          85          1006
#
#    Wind_Speed_m_s Weather_Condition
# 0            0.58              Rain
# 1            7.23              Rain
# 2            5.35            Clouds
# 3            1.78              Rain
# 4            4.59              Rain
